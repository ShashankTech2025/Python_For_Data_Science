# %%
_city="pune"
city="pune"
City="punr"
city5="pune"

# %%
city5
# Out:
# 'pune'

# %%
import keyword

# %%
a=keyword.kwlist

# %%
a
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(a)
# Out:
# 35

# %%
n=int(input("Eter Your Mobile NO :"))
# Out:
# Eter Your Mobile NO : 5

# %%
n
# Out:
# 5

# %%
type(n)
# Out:
# int

# %%
n1=int(input("Eter Your Mobile NO :"))
# Out:
# Eter Your Mobile NO : 10

# %%
n1
# Out:
# 10

# %%
sum1=n+n1

# %%
sum1
# Out:
# 15

# %%
print(type(n))
# Out:
# <class 'int'>

# %%
int(True)
# Out:
# 1

# %%
float(True)
# Out:
# 1.0

# %%
int(False)
# Out:
# 0

# %%
float(False)
# Out:
# 0.0

# %%
n1=float(input("Eter Your Mobile NO :"))
# Out:
# Eter Your Mobile NO : 22

# %%
print(n1)
# Out:
# 22.0

# %%
print("pune",end="\n")
print("MH")
# Out:
# pune
# MH

# %%
print("Number is : ",n1)
# Out:
# Number is :  22.0

# %%
print(f"{n1} is new number")
# Out:
# 22.0 is new number

# %%
num1=int(input("Enter Your First Number :"))
num2=int(input("Enter Your Second Number :"))
add=num1+num2
print(f"The Addition Of {num1} and {num2} is {add}")
# Out:
# Enter Your First Number : 10
# Enter Your Second Number : 45
# The Addition Of 10 and 45 is 55

# %%
num1=int(input("Enter Your First Number :"))
num2=int(input("Enter Your Second Number :"))
add=num1-num2
print(f"The Subtraction  Of {num1} and {num2} is {add}")
# Out:
# Enter Your First Number : 10
# Enter Your Second Number : 5
# The Subtraction  Of 10 and 5 is 5

# %%
num1=int(input("Enter Your First Number :"))
num2=int(input("Enter Your Second Number :"))
add=num1*num2
print(f"The multiplication  Of {num1} and {num2} is {add}")
# Out:
# Enter Your First Number : 5
# Enter Your Second Number : 8
# The multiplication  Of 5 and 8 is 40

# %%
num1=int(input("Enter Your First Number :"))
num2=int(input("Enter Your Second Number :"))
add=num1/num2
print(f"The division  Of {num1} and {num2} is {add}")
# Out:
# Enter Your First Number : 10
# Enter Your Second Number : 5
# The division  Of 10 and 5 is 2.0

# %%
num1=int(input("Enter Your First Number :"))
num2=int(input("Enter Your Second Number :"))
add=num1//num2
print(f"The division  Of {num1} and {num2} is {add}")
# Out:
# Enter Your First Number : 10
# Enter Your Second Number : 5
# The division  Of 10 and 5 is 2

# %%
num1=int(input("Enter Your First Number :"))
sqr=num1**2
print(f"The suqare of {num1} is {sqr}")
# Out:
# Enter Your First Number : 5
# The suqare of 5 is 25

# %%
num1=int(input("Enter Your First Number :"))
sqr_root=num1**(1/2)
print(f"The suqare root  of {num1} is {sqr_root}")
# Out:
# Enter Your First Number : 25
# The suqare root  of 25 is 5.0

# %%
r=int(input("Enter Your redius :"))
area_circle=3.14*(r**2)
print(f"The Area Of circle is  {area_circle}")
# Out:
# Enter Your redius : 5
# The Area Of circle is  78.5

# %%
l=int(input("Enter lenght  :"))
b=int(input("Enter breadth  :"))
area_rect=l*b
print(f"The Area Of Rectangle is {area_rect}")
# Out:
# Enter lenght  : 7
# Enter breadth  : 2
# The Area Of Rectangle is 14

# %%
h=int(input("Enter height   :"))
b=int(input("Enter base   :"))
area_triangle=0.5*h*b
print(f"The Area Of triangle is {area_triangle}")
# Out:
# Enter height   : 8
# Enter base   : 2
# The Area Of triangle is 8.0
